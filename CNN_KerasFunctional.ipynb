# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from os.path import join

import tensorflow as tf 
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.utils import to_categorical

# %%
datax = np.load(join('data', 'MNIST.npy'))
datay = np.load(join('data', 'Label.npy'))

# %%
datax_norm = datax/255
print('최대 : {}, 최소 : {}'.format(np.max(datax_norm), np.min(datax_norm)))
# Out:
# 최대 : 1.0, 최소 : 0.0

# %%
datay_onehot = to_categorical(datay)

# %%
from sklearn.model_selection import train_test_split
trnx, tstx, trny, tsty = train_test_split(datax_norm, datay_onehot, test_size = 0.3, random_state = 111)

# %%
print(trnx.shape)
print(trny.shape)
# Out:
# (42000, 28, 28)
# (42000, 10)
# ERROR! Session/line number was not unique in database. History logging moved to new session 114

# %%
input_shape = (28, 28, 1)

input_tensor = layers.Input(shape = input_shape)

conv1_1 = layers.Conv2D(16, (2,2), padding = 'same')(input_tensor)
conv1_2 = layers.BatchNormalization()(conv1_1)
conv1_3 = layers.Activation("relu")(conv1_2)
conv1_4 = layers.MaxPooling2D((2,2))(conv1_3)

conv2_1 = layers.Conv2D(32, (2,2), padding = 'same')(conv1_4)
conv2_2 = layers.BatchNormalization()(conv2_1)
conv2_3 = layers.Activation("relu")(conv2_2)
conv2_4 = layers.Dropout(0.2)(conv2_3)

flatted = layers.Flatten()(conv2_4)

dense1 = layers.Dense(64, activation = 'relu')(flatted)
dense2 = layers.Dense(32, activation = 'relu')(dense1)
output_class = layers.Dense(5, activation = "softmax")(dense2)

cnn_fmodel = models.Model(input_tensor, output_class)
cnn_fmodel.compile(optimizer='Adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2022-05-04 12:25:46.050228: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-05-04 12:25:46.141706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.141922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3050 computeCapability: 8.6
# coreClock: 1.845GHz coreCount: 20 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 208.65GiB/s
# 2022-05-04 12:25:46.144671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-04 12:25:46.192215: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-05-04 12:25:46.219297: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-05-04 12:25:46.226286: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-05-04 12:25:46.277142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-05-04 12:25:46.285712: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-05-04 12:25:46.376890: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-05-04 12:25:46.377208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.377321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.377356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2022-05-04 12:25:46.377654: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2022-05-04 12:25:46.422294: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3686400000 Hz
# 2022-05-04 12:25:46.425115: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f84546a360 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-04 12:25:46.425203: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-05-04 12:25:46.516249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.516353: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f8454414a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-05-04 12:25:46.516361: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2022-05-04 12:25:46.516475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.516759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3050 computeCapability: 8.6
# coreClock: 1.845GHz coreCount: 20 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 208.65GiB/s
# 2022-05-04 12:25:46.516794: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-04 12:25:46.516803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-05-04 12:25:46.516809: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-05-04 12:25:46.516817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-05-04 12:25:46.516823: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-05-04 12:25:46.516829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-05-04 12:25:46.516836: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-05-04 12:25:46.516909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.516977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.517010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2022-05-04 12:25:46.517602: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-04 12:25:46.518026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-04 12:25:46.518030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2022-05-04 12:25:46.518034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2022-05-04 12:25:46.518077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.518243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 12:25:46.518308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7074 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6)

# %%
cnn_fmodel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 16)        80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 16)        64
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        2080
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                401472
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 406,069
# Trainable params: 405,973
# Non-trainable params: 96
# _________________________________________________________________

# %%
trnx_reshape = trnx.reshape(-1,28,28,1)
tstx_reshape = tstx.reshape(-1,28,28,1)
trnx_reshape.shape
# Out:
# (42000, 28, 28, 1)

# %%
history = cnn_fmodel.fit(trnx_reshape, trny, validation_data = [tstx_reshape, tsty], batch_size = 10, epochs = 10)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3447/2078233165.py", line 1, in <module>
#     history = cnn_fmodel.fit(trnx_reshape, trny, validation_data = [tstx_reshape, tsty], batch_size = 10, epochs = 10)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 235, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 593, in _process_training_inputs
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 646, in _process_inputs
#     x, y, sample_weight=sample_weights)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2383, in _standardize_user_data
#     batch_size=batch_size)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2489, in _standardize_tensors
#     y, self._feed_loss_fns, feed_output_shapes)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py", line 810, in check_loss_and_target_compatibility
#     ' while using as loss `' + loss_name + '`. '
# ValueError: A target array with shape (42000, 10) was passed for an output of shape (None, 5) while using as loss `categorical_crossentropy`. This loss expects targets to have the same shape as the output.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3447/2078233165.py", line 1, in <module>
#     history = cnn_fmodel.fit(trnx_reshape, trny, validation_data = [tstx_reshape, tsty], batch_size = 10, epochs = 10)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 235, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 593, in _process_training_inputs
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 646, in _process_inputs
#     x, y, sample_weight=sample_weights)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2383, in _standardize_user_data
#     batch_size=batch_size)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2489, in _standardize_tensors
#     y, self._feed_loss_fns, feed_output_shapes)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py", line 810, in check_loss_and_target_compatibility
#     ' while using as loss `' + loss_name + '`. '
# ValueError: A target array with shape (42000, 10) was passed for an output of shape (None, 5) while using as loss `categorical_crossentropy`. This loss expects targets to have the same shape as the output.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3541, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2091, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3447/2078233165.py", line 1, in <module>
#     history = cnn_fmodel.fit(trnx_reshape, trny, validation_data = [tstx_reshape, tsty], batch_size = 10, epochs = 10)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 235, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 593, in _process_training_inputs
#     use_multiprocessing=use_multiprocessing)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py", line 646, in _process_inputs
#     x, y, sample_weight=sample_weights)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2383, in _standardize_user_data
#     batch_size=batch_size)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 2489, in _standardize_tensors
#     y, self._feed_loss_fns, feed_output_shapes)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py", line 810, in check_loss_and_target_compatibility
#     ' while using as loss `' + loss_name + '`. '
# ValueError: A target array with shape (42000, 10) was passed for an output of shape (None, 5) while using as loss `categorical_crossentropy`. This loss expects targets to have the same shape as the output.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3541, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2091, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
#     return runner(coro)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3463, in run_ast_nodes
#     self.showtraceback()
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2091, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2088, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/questionnote/miniconda3/envs/tensorflow/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
